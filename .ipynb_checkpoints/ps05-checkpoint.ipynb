# %% [markdown]
# ## Victor Greene Section B

# %% [markdown]
# DS 256 Data Science Programming, Fall 2024
#
# Prof Eatai Roth
#
# ## Problem Set 5
# Due 11/14/2024 by 8p

# %% [markdown]
# ## Titanic Pandas
# (sounds cute...is not)
#
# In this assignment, we'll explore the titanic training data set. These data represent a portion of the passenger manifest of the Titanic, detailing the passengers and whether or not they survived the fateful crash.
#
# The columns are mostly self-explanatory. Key to less-obvious columns:
#  - Sex - male=1 / female=0
#  - Parch - number of parents/children traveling with
#  - SibSp - numbers of siblings/spouses traveling with
#  - PClass - ticket class (like first class, business, economy)
#
#
#  To start, you should import packages, ```pandas``` (as pd) and ```matplotlib.pyplot``` (as plt). Then load the data from ```titanic_train_clean.csv``` into a pandas dataframe.
#
#  Feel free to add more code blocks if needed. When making figures, don't forget to label axes and provide titles and legends when appropriate.

# %%
# Add the boilerplate code for importing the required packages and data
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("titanic.csv")
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp  Survived            Ticket Title  Family_Size
# 0       3    1      1         0         A/5 21171    Mr            1
# 1       1    0      1         1          PC 17599   Mrs            1
# 2       3    0      0         1  STON/O2. 3101282  Miss            0
# ...

# %% [markdown]
# ## Homework Problems
#
# For each of the problems, you'll write some code to find the answer. If there is a written/short answer component, use the provided text field.

# %% [markdown]
# ### Problem 1
#
#  - How many passengers are recorded in this log?
#  - What percentage are male?
#  - What percentage survived?
#
# Hint: You can find these three answers with a single command.

# %%
'''your code here'''
data.describe()
# Out:
#               Age        Fare       Parch  PassengerId      Pclass  \
# count  891.000000  891.000000  891.000000   891.000000  891.000000
# mean    29.445196   32.204208    0.381594   446.000000    2.308642
# std     13.244896   49.693429    0.806057   257.353842    0.836071
# min      0.420000    0.000000    0.000000     1.000000    1.000000
# 25%     22.000000    7.910400    0.000000   223.500000    2.000000
# 50%     30.000000   14.454200    0.000000   446.000000    3.000000
# 75%     35.500000   31.000000    0.000000   668.500000    3.000000
# max     80.000000  512.329200    6.000000   891.000000    3.000000
#
#               Sex       SibSp    Survived  Family_Size
# count  891.000000  891.000000  891.000000   891.000000
# mean     0.647587    0.523008    0.383838     0.904602
# std      0.477990    1.102743    0.486592     1.613459
# min      0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000     0.000000
# ...

# %% [markdown]
# Your written answer:
#
#  - 891
#  - 65%
#  - 38%

# %% [markdown]
# ### Problem 2:
#
#  - What percentage of female passengers survived?
#  - What percentage of male passengers survived?

# %%
'''your code here'''
sex_groupby = data.groupby(['Sex']).agg({"Survived":"mean"})
sex_groupby
# Out:
#      Survived
# Sex
# 0    0.742038
# 1    0.188908

# %% [markdown]
# Your written answer:
#
#  - 74%
#  - 19%

# %% [markdown]
# ### Problem 3
#
# Use ```groupby``` and ```agg``` to find the percentage of the total tickets and the survivorship percentage for each class of ticket.

# %%
'''your code here'''
groupby_class = data.groupby(["Pclass"]).agg({"Survived": "mean", "Pclass": lambda x: len(x)/len(data)})
groupby_class
# Out:
#         Survived    Pclass
# Pclass
# 1       0.629630  0.242424
# 2       0.472826  0.206510
# 3       0.242363  0.551066

# %% [markdown]
# Your written answer:
#
#  - Class 1
#     - % tickets: 24%
#     - % survivorship: 63%
# - Class 2
#     - % tickets: 21%
#     - % survivorship: 47%
# - Class 3
#     - % tickets: 55%
#     - % survivorship: 24%

# %% [markdown]
# ### Problem 4
#
# Create two new dataframes corresponding to survivors and non-survivors keeping only the columns: age, name, and sex. Display the first five rows of these new dataframes.
#
# Create a figure showing the distribution of age by sex and survivorship (four histograms on the same axes: male-survivors, female-survivors, male-unlucky, female-unlucky). Choose colors and histtype (see the [documentation for histogram](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)) to make this figure easy to read and interpret.

# %%
'''Your code here'''
#I wasn't sure how you wanted this so I did it 2 ways.

#Method 1

columns_to_keep = ["Age", "Name", "Sex"]

survivors = data[data["Survived"] == 1][columns_to_keep]
non_survivors = data[data["Survived"] == 0][columns_to_keep]

display(survivors.head())
display(non_survivors.head())

fig, ax = plt.subplots(1, 4, figsize = (16, 4))

ax[0].hist(survivors[survivors["Sex"] == 0]["Age"], color = "pink")
ax[0].set_title("Female Survivors")

ax[1].hist(survivors[survivors["Sex"] == 1]["Age"], color = "blue")
ax[1].set_title("Male Survivors")

ax[2].hist(non_survivors[non_survivors["Sex"] == 0]["Age"], color = "pink")
ax[2].set_title("Female Non-Survivors")

ax[3].hist(non_survivors[non_survivors["Sex"] == 1]["Age"], color = 'blue')
ax[3].set_title("Male Non-Survivors")

for i in range(4):
    ax[i].set_xlabel("Age")
    ax[i].set_ylabel("Number of Survivors")
    ax[i].set_xlim(0, data["Age"].max())
    ax[i].set_ylim(0, 220)

plt.subplots_adjust(wspace=0.35) 

plt.show()
# Out:
#     Age                                               Name  Sex
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2  26.0                             Heikkinen, Miss. Laina    0
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 8  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0
# 9  14.0                Nasser, Mrs. Nicholas (Adele Achem)    0
#     Age                            Name  Sex
# 0  22.0         Braund, Mr. Owen Harris    1
# 4  35.0        Allen, Mr. William Henry    1
# 5  30.0                Moran, Mr. James    1
# 6  54.0         McCarthy, Mr. Timothy J    1
# 7   2.0  Palsson, Master. Gosta Leonard    1

# %%
fig, ax = plt.subplots(1, 1, figsize = (16, 4))

ax.hist(survivors[survivors["Sex"] == 0]["Age"], color = "pink", alpha = .4, label = "Female Survivors")

ax.hist(survivors[survivors["Sex"] == 1]["Age"], color = "blue", alpha = .4, label = "Male Survivors")

ax.hist(non_survivors[non_survivors["Sex"] == 0]["Age"], color = "red", alpha = .4, label = "Female Unlucky")

ax.hist(non_survivors[non_survivors["Sex"] == 1]["Age"], color = 'purple', alpha = .3, label = "Female Survivors")

ax.set_title("Survivorship by Gender and Age", fontsize = 16)
ax.set_xlabel("Age", fontsize = 12)
ax.set_ylabel("Number of Passengers", fontsize = 12)
plt.legend(fontsize = 11)
plt.show()

# %% [markdown]
# ### Problem 5
#
# Now that we've inspected the data, let's build a classifier (you'll compare two models) that predicts which passengers survived. These are the steps you should take:
#
#  - Choose your features. The label will be survivorship.
#  - Split the data into training and test sets.
#  - Standardize the values using StandardScaler
#  - Choose two of the following model types: KNN, SVM, Decision Tree. Create those models and select hyper-parameters.
#  - Fit your models to the training data.
#  - Apply the fit models to create predictions from the test data.
#  - For each model, create a confusion matrix for the training and test data. You may want to revisit the hyper-parameters and re-fit the models.
#
#  - Answer the questions at the bottom of the code block.

# %%
'''Your code here'''
label = ['Survived']
features = ['Sex', 'Age', "Pclass", "Family_Size"]
#We want to use all of the informative data we can get

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data[features], data[label], test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

tree_clf = DecisionTreeClassifier(max_depth = 4)
tree_clf.fit(X_train, y_train)

#shows us all parameters of model
#tree_clf.__dict__

#filled = True means we have different background colors
#value = [444, 267] means 444 drowned, 267 survived
fig, ax = plt.subplots(1, 1, figsize = (15, 6))
plot_tree(tree_clf, feature_names = features, class_names = ["Drowned", "Survived"], filled = True, fontsize = 8)
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

y_tree_train = tree_clf.predict(X_train)
y_tree_test = tree_clf.predict(X_test)

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ConfusionMatrixDisplay.from_predictions(y_train, y_tree_train, normalize = 'true', display_labels = ["Drowned", "Survived"], ax = ax[0])
ConfusionMatrixDisplay.from_predictions(y_test, y_tree_test, normalize = 'true', display_labels = ["Drowned", "Survived"], ax = ax[1])

ax[0].set_title("training")
ax[1].set_title("testing")
fig.suptitle("Decision Tree")

plt.subplots_adjust(wspace=0.35) 
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(X_train)

Xs_train = ss.transform(X_train)
Xs_test = ss.transform(X_test)

#.values gets the values then ravel makes higher dimensional data 1D
ys_train = y_train.values.ravel()
ys_test = y_test.values.ravel()

knn_clf = KNeighborsClassifier(n_neighbors = 15)
knn_clf.fit(Xs_train, ys_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
y_knn_train = knn_clf.predict(Xs_train)
y_knn_test = knn_clf.predict(Xs_test)

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ConfusionMatrixDisplay.from_predictions(y_train, y_knn_train, normalize = 'true', display_labels = ["Drowned", "Survived"], ax = ax[0])
ConfusionMatrixDisplay.from_predictions(y_test, y_knn_test, normalize = 'true', display_labels = ["Drowned", "Survived"], ax = ax[1])

ax[0].set_title("training")
ax[1].set_title("testing")
fig.suptitle("KNN")

plt.subplots_adjust(wspace=0.35) 
plt.show()

# %% [markdown]
# #### **Questions**
#
# How does the model performance on the test data compare to the performance on the training data?
#
#  - Model performance on the test data is very similar to how it preformed on the training data. For both the classification tree model and the KNN model, accuracy for drowned passengers was within 1% of eachother for the test and training datasets. For both models, accuracy for surviving passengers was about 5% better on the training set when compared to the testing set.
#
#
# Which models did you fit and which worked better?
#
#  - We fit a classification tree model and a KNN model to the data. The models had very similar performances, but in my view the KNN model outperformed the classification tree model. To compare the effectiveness of the models, I compared their performance on the test data. The classification tree model had 94% accuracy for drowned passengers and 65% accuracy for surviving passengers. The KNN model had 89% accuracy for drowned passengers and 70% accuracy for surviving passengers. Seeing as both models performed well on the drowned passenger data, I thought it was most important for a model to do better on what they both did poorly, which was classifying surviving passengers. Since the KNN model performed better on the surviving passenger data than the classification tree model, I think it worked better.
